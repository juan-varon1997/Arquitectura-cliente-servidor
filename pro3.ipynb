# %%
global lista
lista = list()

class Hospital():
    hospital_id = ""
    hospital_name = ""

class Doctor(Hospital):
    doctor_id = ""
    doctor_name = ""
    speciality = ""

def RegistrarDoctor():
    print("\n")
    print("REGISTRO")
    h = Hospital()
    
    h.hospital_id = input("Ingrese id de hospital: ")
    h.hospital_name = input("Ingrese nombre de hospital: ")
    h.doctor_id = input("Ingrese cedula: ")
    h.doctor_name = input("Ingrese nombre: ")
    h.speciality = input("Ingrese especialidad: ")
    
    lista.append(h)
    
    print("\n")
    
def ListarDoctor():
    print("\n")
    print("LISTADO")
    print("\n")
    
    for h in lista:
        print("Id de hospital: ", h.hospital_id, ", nombre del hospital: ", h.hospital_name,
             ", Id doctor: ", h.doctor_id, ", nombre del doctor: ", h.doctor_name, 
                ", especialidad del doctor: ", h.speciality)

        print("\n")
    
def BuscarDoctor():
    print("\n")
    print("BUSQUEDA POR ID DOCTOR")
    
    doctor_id = input("Ingrese la cedula a buscar: ")
    
    for h in lista:
        if h.doctor_id == doctor_id:
            print("Id de hospital: ", h.hospital_id, ", nombre del hospital: ", h.hospital_name,
             ", Id doctor: ", h.doctor_id, ", nombre del doctor: ", h.doctor_name, 
                ", especialidad del doctor: ", h.speciality)
    print("\n")

def BuscarHospital():
    print("\n")
    print("BUSQUEDA POR NOMBRE DE HOSPITAL")
    
    hospital_name = input("Ingrese el nombre de hospital a buscar: ")
    
    for h in lista:
        if h.hospital_name == hospital_name:
            d = h
            print("Id de hospital: ", h.hospital_id, ", nombre del hospital: ", h.hospital_name,
             ", Id doctor: ", h.doctor_id, ", nombre del doctor: ", h.doctor_name, 
                ", especialidad del doctor: ", h.speciality)
    print("\n")

""""def EliminarDoctor():
    print("\n")
    print("ELIMINAR DOCTOR")
    
    doctor_id = input("Ingrese la cedula del doctor a eliminar: ")
    
    for h in lista:
        if h.doctor_id == doctor_id:
            print(hospital_id.pop(h), hospital_name.pop(h), doctor_id.pop(h), doctor_name.pop(h), speciality.pop(h))
    print("\n")""" 
    
def Salir():
    print("\n")
    print("Gracias...")
    
def menu():
    op = 0
    
    while op != 6:
        print("Menu")
        print("1. Registrar doctor")
        print("2. Listar doctor")
        print("3. Buscar por identificacion de doctor")
        print("4. Buscar por nombre de hospital")
        print("5. Eliminar doctor")
        print("6. Salir")
        op = input("Digite opcion: ")
        
        if op == "1":
            RegistrarDoctor()
        elif op == "2":
            ListarDoctor()
        elif op == "3":
            BuscarDoctor()
        elif op == "4":
            BuscarHospital()
        elif op == "5":
            EliminarDoctor()
        elif op == "6":
            Salir()
            
menu()
# Out:
# Menu
# 1. Registrar doctor
# 2. Listar doctor
# 3. Buscar por identificacion de doctor
# 4. Buscar por nombre de hospital
# 5. Eliminar doctor
# 6. Salir
